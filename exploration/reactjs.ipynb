# %%
# %load_ext autoreload
# %autoreload 2

# %%
from variable_importance.revealjs import create_revealjs_presentation, RevealJSAgent
from variable_importance.memory.context_rag import ContextRAG
from variable_importance.utils.output_manager import OutputManager

# %%
workflow_id = "workflow_20251128_000315"

# %%
rag = ContextRAG(
    collection_name=workflow_id,
    persist_directory='../cache/rag_db',
    chunk_size=1500,
    chunk_overlap=50,
)
# Out:
# 2025-12-06 00:41:32.523 | INFO     | variable_importance.memory.context_rag:__init__:62 - 📝 TextChunker initialized (chunk_size=1500, overlap=50, contextual=True)
# 2025-12-06 00:41:32.530 | INFO     | variable_importance.memory.context_rag:__init__:578 - 📚 ContextRAG initialized: workflow_20251128_000315
# 2025-12-06 00:41:32.807 | INFO     | variable_importance.memory.context_rag:__init__:579 -    Stored documents: 10682

# %%
output_mgr = OutputManager(
    workflow_id=workflow_id,
    base_results_dir='../results'
)
# Out:
# 2025-12-06 00:41:33.742 | INFO     | variable_importance.utils.output_manager:__init__:95 - 📁 OutputManager initialized: /Users/redam94/Coding/Ideas/variable_importance/results/workflow_20251128_000315

# %%
# result = await create_revealjs_presentation(
#     topic="Bayesian vs Frequentist Analysis",
#     workflow_id=workflow_id,
#     stage_name="analysis",
#     workflow_rag=rag,           # your existing ContextRAG
#     output_manager=output_mgr,  # for image discovery
#     user_id="user123",
#     num_slides=5,
# )

# %%
agent = RevealJSAgent(
    llm_model="qwen3:30b",
    workflow_rag=rag,
    output_manager=output_mgr,
    user_id='mattr',
    max_iterations=2
)

# %% [markdown]
# (setup, slides, fragments, backgrounds, transitions, themes, code)

# %%
agent.add_style_rule(
    "Use descriptive titles for each slide that summarize the main point. Avoid vague titles.",
    "slides"
)
# Out:
# 2025-12-06 00:59:30.995 | INFO     | variable_importance.revealjs.style_memory:add_rule:163 - 📝 Added style rule: Use descriptive titles for each slide that summari... (slides)
# '0d685cc7a5edfe4e4892a1b62b2f3c07'

# %%
agent.add_style_rule(
    ("Try to aim for only 3 to 5 bullet points per slide to keep information digestible. If there are more points, consider splitting into multiple slides."
    "For text-heavy slides, use concise phrases rather than full sentences to enhance readability."),
    "slides"
)
# Out:
# 2025-12-06 00:59:32.278 | INFO     | variable_importance.revealjs.style_memory:add_rule:163 - 📝 Added style rule: Try to aim for only 3 to 5 bullet points per slide... (slides)
# '655550d570b7fafde33f63825f2f7bae'

# %%
result = await agent.create_presentation(
    topic="Bayesian vs Frequentist Analysis",
    workflow_id=workflow_id,
    stage_name="analysis",
    num_slides=10,
    custom_instructions=(
        "Think carefully about the target audience, which consists of beginners in statistics. "
        "Create an engaging and informative presentation that clearly outlines the key differences between Bayesian and Frequentist statistical approaches. "
        "Focus on clarity and simplicity in slide design. "
        "Be thoughtful about the flow of information to ensure the audience can easily follow along. "
        "Be thorough in explaining complex concepts. "
        "Incorporate relevant information from the RAG to support key points. "
        "Use quotes, data points, or examples from the context where appropriate. "
        "Avoid overcrowding slides with too much text or too many visuals. "
        "This is an educational presentation aimed at helping beginners understand the differences between Bayesian and Frequentist statistical approaches. "
    ),
    theme='black',
)
# Out:
# 2025-12-06 00:59:32.928 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Starting presentation generation workflow...
# 2025-12-06 00:59:32.931 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Gathering context with RAG agent...
# 2025-12-06 01:00:00.706 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 15 relevant context chunks
# 2025-12-06 01:00:08.579 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 15 relevant context chunks
# 2025-12-06 01:00:19.038 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 15 relevant context chunks
# 2025-12-06 01:00:23.097 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 15 relevant context chunks
# 2025-12-06 01:00:34.924 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 15 relevant context chunks
# 2025-12-06 01:00:41.321 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 20 relevant context chunks
# 2025-12-06 01:00:55.218 | DEBUG    | variable_importance.revealjs.docs_rag:query:174 - 🔍 Found 5 snippets for: two column layout...
# 2025-12-06 01:01:16.210 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 30 relevant context chunks
# 2025-12-06 01:01:37.231 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Gathered 6 context chunks, 1 plot analyses
# 2025-12-06 01:01:37.235 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Enriching 12 images with RAG descriptions...
# 2025-12-06 01:01:37.602 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 30 relevant context chunks
# 2025-12-06 01:01:37.602 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 survival_by_class.png: Found RAG description
# 2025-12-06 01:01:37.602 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 correlation_matrix.png: Found RAG description
# 2025-12-06 01:01:37.603 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 fare_vs_age_scatter_plot.png: Found RAG description
# 2025-12-06 01:01:37.603 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 trace_plots.png: Found RAG description
# 2025-12-06 01:01:37.603 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 bayesian_model_posterior.png: Found RAG description
# 2025-12-06 01:01:37.603 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 ordinal_model_ppc.png: Found RAG description
# 2025-12-06 01:01:37.603 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 distribution_plots.png: Found RAG description
# 2025-12-06 01:01:37.604 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 correlation_heatmap.png: Found RAG description
# 2025-12-06 01:01:37.604 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 pclass_distribution.png: Found RAG description
# 2025-12-06 01:01:37.604 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 bayesian_model_trace.png: Found RAG description
# 2025-12-06 01:01:37.605 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 posterior_distributions.png: Found RAG description
# 2025-12-06 01:01:37.605 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   📊 ordinal_model_trace.png: Found RAG description
# 2025-12-06 01:01:37.605 | INFO     | variable_importance.revealjs.agent:_get_images_with_descriptions:654 - 📊 Enriched 12 images with RAG descriptions
# 2025-12-06 01:01:37.606 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Planning presentation (iteration 1)...
# 2025-12-06 01:02:13.293 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Planned 10 slides
# 2025-12-06 01:02:13.296 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS: Verifying slide content against RAG...
# 2025-12-06 01:02:13.297 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   Verifying slide 2: Core Philosophy
# 2025-12-06 01:02:13.634 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 10 relevant context chunks
# 2025-12-06 01:02:36.699 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:     ✓ Verified (score: 0.50)
# 2025-12-06 01:02:36.701 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   Verifying slide 3: Interpreting Results
# 2025-12-06 01:02:37.034 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 10 relevant context chunks
# 2025-12-06 01:03:06.699 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:     ✓ Verified (score: 1.00)
# 2025-12-06 01:03:06.701 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   Verifying slide 4: Key Difference: Credible Intervals vs p-values
# 2025-12-06 01:03:07.061 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 10 relevant context chunks
# 2025-12-06 01:03:31.169 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:     ✓ Verified (score: 0.50)
# 2025-12-06 01:03:31.171 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   Verifying slide 5: Evaluating Bayesian Inferences
# 2025-12-06 01:03:31.489 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 10 relevant context chunks
# 2025-12-06 01:03:43.951 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:     ✓ Verified (score: 1.00)
# 2025-12-06 01:03:43.953 | INFO     | variable_importance.revealjs.agent:_emit:142 - 🎨 RevealJS:   Verifying slide 6: When to Use Bayesian
# 2025-12-06 01:03:44.292 | INFO     | variable_importance.memory.context_rag:query_relevant_context:1004 - 🔍 Retrieved 10 relevant context chunks
