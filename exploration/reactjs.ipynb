# %%
# %load_ext autoreload
# %autoreload 2

# %%
from variable_importance.revealjs import create_revealjs_presentation, RevealJSAgent
from variable_importance.memory.context_rag import ContextRAG
from variable_importance.utils.output_manager import OutputManager

# %%
workflow_id = "workflow_20251129_122152"

# %%
rag = ContextRAG(
    collection_name=workflow_id,
    persist_directory='../cache/rag_db',
    chunk_size=1500,
    chunk_overlap=50,
)
# Out:
# 2025-12-05 23:45:30.908 | INFO     | variable_importance.memory.context_rag:__init__:62 - 📝 TextChunker initialized (chunk_size=1500, overlap=50, contextual=True)
# 2025-12-05 23:45:30.967 | INFO     | variable_importance.memory.context_rag:__init__:578 - 📚 ContextRAG initialized: workflow_20251129_122152
# 2025-12-05 23:45:31.200 | INFO     | variable_importance.memory.context_rag:__init__:579 -    Stored documents: 806

# %%
output_mgr = OutputManager(
    workflow_id=workflow_id,
    base_results_dir='../results'
)
# Out:
# 2025-12-05 23:45:31.917 | INFO     | variable_importance.utils.output_manager:__init__:95 - 📁 OutputManager initialized: /Users/redam94/Coding/Ideas/variable_importance/results/workflow_20251129_122152

# %%
# result = await create_revealjs_presentation(
#     topic="Bayesian vs Frequentist Analysis",
#     workflow_id=workflow_id,
#     stage_name="analysis",
#     workflow_rag=rag,           # your existing ContextRAG
#     output_manager=output_mgr,  # for image discovery
#     user_id="user123",
#     num_slides=5,
# )

# %%
agent = RevealJSAgent(
    llm_model="qwen3:8b",
    workflow_rag=rag,
    output_manager=output_mgr,
    user_id='mattr',
    max_iterations=2
)
# Out:
# 2025-12-05 23:45:43.222 | INFO     | variable_importance.revealjs.docs_rag:__init__:76 - 📚 RevealJS DocsRAG initialized: 19 snippets
# 2025-12-05 23:45:43.228 | INFO     | variable_importance.revealjs.style_memory:__init__:78 - 📝 StyleMemory initialized for user: mattr (2 rules)

# %%
agent.add_style_rule(
    "Use descriptive titles for each slide that summarize the main point. Avoid vague titles.",
    "title"
)
# Out:
# 2025-12-05 23:42:44.966 | INFO     | variable_importance.revealjs.style_memory:add_rule:163 - 📝 Added style rule: Use descriptive titles for each slide that summari... (title)
# '50a6ca4dfabc946d9c13aaab7566348c'

# %%
agent.add_style_rule(
    ("Try to aim for only 3 to 5 bullet points per slide to keep information digestible. If there are more points, consider splitting into multiple slides."
    "For text-heavy slides, use concise phrases rather than full sentences to enhance readability."),
    "bullet_points"
)
# Out:
# 2025-12-05 23:43:58.836 | INFO     | variable_importance.revealjs.style_memory:add_rule:163 - 📝 Added style rule: Try to aim for only 3 to 5 bullet points per slide... (bullet_points)
# '4af42b65af55ff395c988baaf5576d28'

# %%
agent.create_presentation?
# Out:
# Signature:
# agent.create_presentation(
#     topic: str,
#     workflow_id: str,
#     stage_name: str,
#     num_slides: int = 6,
#     custom_instructions: str = '',
#     theme: Optional[str] = None,
#     transition: Optional[str] = None,
#     color_primary: Optional[str] = None,
#     color_secondary: Optional[str] = None,
# ) -> variable_importance.revealjs.models.GeneratedPresentation
# Docstring: Create a Reveal.js presentation using the full workflow.
# File:      ~/Coding/Ideas/variable_importance/src/variable_importance/revealjs/agent.py
# Type:      method

# %%
result = await agent.create_presentation(
    topic="Bayesian vs Frequentist Analysis",
    workflow_id=workflow_id,
    stage_name="analysis",
    num_slides=10,
    custom_instructions=(
        "Focus on clarity and simplicity in slide design. "
        "Be thoughtful about the flow of information to ensure the audience can easily follow along. "
        "Be thorough in explaining complex concepts. "
        "Incorporate relevant information from the RAG to support key points. "
        "Use quotes, data points, or examples from the context where appropriate. "
        "Avoid overcrowding slides with too much text or too many visuals. "
        "This is an educational presentation aimed at helping beginners understand the differences between Bayesian and Frequentist statistical approaches. "
    ),
    theme='black',
)
# Out:
# <coroutine object RevealJSAgent.create_presentation at 0x121b27b60>
